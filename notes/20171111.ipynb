# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
# Is df data frame?
df_wine=pd.read_csv("wine.csv")
feat_labels=df_wine.columns[2:]
df_wine.head()
# Out:
#    Unnamed: 0  Class label  Alcohol  Malic acid   Ash  Alcalinity of ash  \
# 0           0            1    14.23        1.71  2.43               15.6
# 1           1            1    13.20        1.78  2.14               11.2
# 2           2            1    13.16        2.36  2.67               18.6
# 3           3            1    14.37        1.95  2.50               16.8
# 4           4            1    13.24        2.59  2.87               21.0
#
#    Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# 0        127           2.80        3.06                  0.28
# 1        100           2.65        2.76                  0.26
# 2        101           2.80        3.24                  0.30
# 3        113           3.85        3.49                  0.24
# 4        118           2.80        2.69                  0.39
#
#    Proanthocyanins  Color intensity   Hue  OD280/OD315 of diluted wines  \
# 0             2.29             5.64  1.04                          3.92
# 1             1.28             4.38  1.05                          3.40
# 2             2.81             5.68  1.03                          3.17
# 3             2.18             7.80  0.86                          3.45
# 4             1.82             4.32  1.04                          2.93
#
#    Proline
# 0     1065
# 1     1050
# 2     1185
# 3     1480
# 4      735

# %%
import os
os.getcwd()
# Out:
# '/Users/hidehiro/code/hidehiro98/ml_raschka_sugakubunka'

# %%
from sklearn.model_selection import train_test_split
X, y = df_wine.iloc[:, 2:].values, df_wine.iloc[:, 1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

forest=RandomForestClassifier(n_estimators=10000)
forest.fit(X_train, y_train)
importances = forest.feature_importances_
indices=np.argsort(importances)[::-1]
for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f+1, 30, feat_labels[indices[f]], importances[indices[f]]))
# Out:
#  1) Flavanoids                     0.180020
#  2) Proline                        0.157129
#  3) Color intensity                0.140986
#  4) Alcohol                        0.124256
#  5) OD280/OD315 of diluted wines   0.113709
#  6) Hue                            0.079848
#  7) Total phenols                  0.050295
#  8) Malic acid                     0.039971
#  9) Magnesium                      0.029942
# 10) Proanthocyanins                0.028970
# 11) Alcalinity of ash              0.027391
# 12) Ash                            0.014860
# 13) Nonflavanoid phenols           0.012622

# %%
# %matplotlib inline
wine_dataframe = pd.DataFrame(X, columns = df_wine.columns[2:])
pd.plotting.scatter_matrix(wine_dataframe, c=y, figsize = (10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a17635e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c6ca9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c71cc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c798400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c7f76a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c7f76d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c8c13c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c934ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c98bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c9c7cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ca57ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ca6f4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cb21f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cb82710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cbeed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cc55128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ccc6da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cd2b710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cd66b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cdf9080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ce094e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cebde80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cf1d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cf88cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cfe6f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d061c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d0ab208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d11f9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d175b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d1b1a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d23fd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d254860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d30cd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d36d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d3d7ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d436f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d4b1cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d517550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d551940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d5dbe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d5ef780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d6a6be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d7063c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d772a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d7d1da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d84cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d897048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d909828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d95f978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d9997b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1da2ada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d864d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1daf8be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1db56390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dbc3a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dc21d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dc9ba20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dd012b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dd3c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ddc6b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dc56128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1de92978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1def1128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1df5a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dfbbb00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e0376d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e09d048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e0d8320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e153048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e15f780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e20dcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e2714e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e2dab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e337eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e3b3978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e41b320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e4535f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e4ddba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e35ec88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e5a89e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e60a198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e675710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e6d3b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e74f470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7acf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7ee2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e879860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7e3e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e945588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e99ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea103c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea6d828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eaeb208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb47c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb83ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ebfe710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec105f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ecc1438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed19ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed8b278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1edec5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee65080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eec39e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef052b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef922b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1efa3470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f05d0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f0b2860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f11def0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f186278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f1f9cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2616a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2a0208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f321f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f33d668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3eec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f44d518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4bba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f518ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f5948d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f5f9358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f639160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f6bcbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f6d2470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f788908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7e81d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f855748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f8b3ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f92d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f969668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f9dc668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fa34da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1faa7fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fb0d908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f9f60b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fc1c048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fc7a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fcede10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fd537b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fd954a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fe16f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fe32ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fee1d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff43630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ffadba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20014048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a200879e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a200ed470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2012f160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a201b3be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a201c6da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2027ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a202dd2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20346860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a203a8cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a204206a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2048a128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a204c5dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2054d898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20561828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a206186d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20670f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a206e4518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20744978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a207bc358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2081bda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2085ea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a208e6550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a208fc320>]], dtype=object)

# %%
df_wine.iloc[:,1].values

df_wine.iloc[10:20, 3:5]
# Out:
#     Malic acid   Ash
# 10        2.16  2.30
# 11        1.48  2.32
# 12        1.73  2.41
# 13        1.73  2.39
# 14        1.87  2.38
# 15        1.81  2.70
# 16        1.92  2.72
# 17        1.57  2.62
# 18        1.59  2.48
# 19        3.10  2.56

# %%
# %matplotlib inline
y = df_wine.iloc[:,1].values
pd.plotting.scatter_matrix(df_wine.iloc[:,2:7],c=y, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2490bb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a201e9dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff774a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e5bde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d8b32e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d8b3048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23dcfeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2484bda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ab5fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a241c1828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24b08ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24af9eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24dcd908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ce6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25091748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a250e39e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251576a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251b2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251f2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25276940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a25288e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25344780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25395e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a254125c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25472860>]], dtype=object)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

# %%
def plot_learning_curve(estimator, title, x, y, ylim=None, cv=None,
                                           n_jobs=4, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(estimator, x, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid
    
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, 
                                train_scores_mean + train_scores_std, alpha=0.1)
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, 
                                 test_scores_mean + test_scores_std, alpha=0.1)
    plt.plot(train_sizes, train_scores_mean, "o-", label="Training score")
    plt.plot(train_sizes, test_scores_mean, "o-", label="Cross-validation score")
    plt.legend(loc="best")
    return plt

# %%
title = "Learning Curves (DT)"
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
estimator = DecisionTreeClassifier(criterion="entropy", max_depth=3)
plot_learning_curve(estimator, title, X, y, ylim=(0.5, 1.01), cv=cv, n_jobs=-1)
# Out:
# <module 'matplotlib.pyplot' from '/Users/hidehiro/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
indices
# Out:
# array([ 6, 12,  9,  0, 11, 10,  5,  1,  4,  8,  3,  2,  7])

# %%
X_selected, y_selected = X[:, indices[:3]], y
title = "Learning Curves (DT, 3 variables)"
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
estimator = DecisionTreeClassifier(criterion="entropy", max_depth=3)
plot_learning_curve(estimator, title, X_selected, y_selected, ylim=(0.5, 1.01), cv=cv, n_jobs=-1)
# Out:
# <module 'matplotlib.pyplot' from '/Users/hidehiro/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
X_selected, y_selected = X[:, indices[:4]], y
title = "Learning Curves (DT, 3 variables)"
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
estimator = DecisionTreeClassifier(criterion="entropy", max_depth=3)
plot_learning_curve(estimator, title, X_selected, y_selected, ylim=(0.5, 1.01), cv=cv, n_jobs=-1)
# Out:
# <module 'matplotlib.pyplot' from '/Users/hidehiro/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline
mean = [0,0]
cov = [[1, 0.8], [0.8, 1]]
x, y = np.random.multivariate_normal(mean, cov, 100).T
plt.plot(x, y, "x")
plt.axis("equal")
# Out:
# (-2.6497671981955775,
#  4.2926648146187985,
#  -2.6210271534484519,
#  3.4838327257627726)

# %%
X=np.array([x, y]).transpose()
pca=PCA(n_components=2) # もともとの変数の数以下
pca.fit(X)
X_r = pca.transform(X)
plt.plot(X_r[:, 0], X_r[:,1], "x")
plt.axis("equal")
print(pca.explained_variance_ratio_)
# Out:
# [ 0.93060417  0.06939583]

# %%
from sklearn import datasets
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

iris=datasets.load_iris()
X, y, target_names=iris.data, iris.target, iris.target_names
pca=PCA(n_components=2)
pca.fit(X)
X_r=pca.transform(X)

print("explained variance ration (first two components): %s" % str(pca.explained_variance_ratio_))
plt.figure()
for i in range(len(target_names)):
    plt.scatter(X_r[y==i, 0], X_r[y==i, 1], label=target_names[i])
plt.legend()
# Out:
# explained variance ration (first two components): [ 0.92461621  0.05301557]

# %%
# %matplotlib inline
iris_dataframe = pd.DataFrame(X, columns = iris.feature_names)
pd.plotting.scatter_matrix(iris_dataframe, c = y, figsize = (10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a25f34128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26644588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2609f978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26702e48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a26762fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2676d048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a268475f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a268849e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2690cf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a269233c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a269d8d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26a3d470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a26aa8ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26b07e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26b85b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26beb470>]], dtype=object)

# %%
# まずirisを普通にDTで分類してみる
title = "Iris Learning Curves (DT, 3 variables)"
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
estimator = DecisionTreeClassifier(criterion="entropy", max_depth=2)
plot_learning_curve(estimator, title, X, y, ylim=(0.5, 1.01), cv=cv, n_jobs=-1)
# Out:
# <module 'matplotlib.pyplot' from '/Users/hidehiro/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
# PCAした後のデータでやってみる。irisの場合はもともと分類できてしまっているので対して変わらない
title = "Iris PCA Learning Curves (DT, 3 variables)"
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
estimator = DecisionTreeClassifier(criterion="entropy", max_depth=2)
plot_learning_curve(estimator, title, X_r, y, ylim=(0.5, 1.01), cv=cv, n_jobs=-1)
# Out:
# <module 'matplotlib.pyplot' from '/Users/hidehiro/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
# 手書き文字主成分分析
from sklearn import datasets
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

digits=datasets.load_digits()
X, y, target_names=digits.data,digits.target,digits.target_names
pca=PCA(n_components=2)
pca.fit(X)
X_r=pca.transform(X)

print('explained variance ratio (first two components): %s' % str(pca.explained_variance_ratio_))

plt.figure()
for i in range(len(target_names)):
    plt.scatter(X_r[y==i, 0], X_r[y==i, 1], label=target_names[i])
plt.legend()
# Out:
# explained variance ratio (first two components): [ 0.14890594  0.13618771]
